# %% [markdown]
# # Extract Photo Coordinates of data

# %%
import pandas as pd
from soc_module import *

# %%
alameda = geojson.load(open("data/alameda-2010.geojson"))

# %%
new = pd.read_csv('./social_disorder_responses.csv')

# %%
new
# Out:
#                Timestamp                     Email Address  \
# 0                    NaN                               NaN
# 1    10/21/2018 22:08:57      jesslanderos098@berkeley.edu
# 2    10/21/2018 22:10:14           hjs9701282@berkeley.edu
# 3    10/21/2018 22:23:08             etshuere@berkeley.edu
# 4     10/22/2018 0:01:58             jihailin@berkeley.edu
# 5     10/22/2018 0:08:49             jquach50@berkeley.edu
# 6     10/22/2018 0:09:49          stephdiaz25@berkeley.edu
# 7    10/22/2018 10:52:35          jameslu9748@berkeley.edu
# 8    10/22/2018 12:00:25            zacharywu@berkeley.edu
# 9    10/22/2018 12:36:50            park_eecs@berkeley.edu
# 10   10/22/2018 13:49:40            rachel.ba@berkeley.edu
# 11   10/22/2018 23:01:24             chloesty@berkeley.edu
# 12   10/22/2018 15:17:51     kevinrojas199723@berkeley.edu
# 13   10/22/2018 15:25:57        justin.yj.lee@berkeley.edu
# 14   10/22/2018 16:38:09              ppatino@berkeley.edu
# ...

# %%
new = new.iloc[136:,:]

# %%
new
# Out:
#                Timestamp                Email Address             Name  \
# 136  10/29/2018 12:40:23       afrancojr@berkeley.edu         Alfonso
# 137  10/29/2018 15:00:33       omarkahly@berkeley.edu       Omar Kahly
# 138  10/29/2018 15:54:25  nikita_acharya@berkeley.edu   Nikita Acharya
# 139  10/29/2018 17:46:32     adrianvan13@berkeley.edu       Adrian Van
# 140  10/29/2018 19:54:05          plopez@berkeley.edu  Priscilla Lopez
#
#      Census Tract  \
# 136        4214.0
# 137        4235.0
# 138        4014.0
# 139        4205.0
# 140        4033.0
#
#      On a scale of 1 - 5, where 1 is "None" and 5 is "A Lot", how many empty beer or liquor bottles are visible in streets, yards, or alleys?   \
# 136                                                1.0
# 137                                                2.0
# 138                                                1.0
# 139                                                1.0
# 140                                                1.0
# ...

# %%
get_coords(new, alameda, "sociology-130ac")
# Out:
# C:\Users\keiko\OneDrive\Desktop\GoBears\SOC-130AC\soc_module.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data['Census Tract'] = data['Census Tract'].apply(fix_tract)
# C:\Users\keiko\OneDrive\Desktop\GoBears\SOC-130AC\soc_module.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data['Image #' + str(j)+ ' coordinates'] = image_coords
#                Timestamp                Email Address             Name  \
# 136  10/29/2018 12:40:23       afrancojr@berkeley.edu         Alfonso
# ...

# %%
old = pd.read_csv('./data/fa18-soc-disorder.csv')

# %%
len(old)
# Out:
# 135

# %%
len(new)
# Out:
# 5

# %%
combined = pd.concat([old.iloc[0:,1:],new])
len(combined)
# Out:
# 140

# %%
combined.to_csv('./data/fa18-soc-disorder-update.csv')

# %%
test = pd.read_csv('./data/fa18-soc-disorder-update.csv')

# %%
prev = pd.read_csv('./data/fa18-soc-disorder.csv')

# %%
len(prev.columns)
# Out:
# 40

# %%
len(test.columns)
# Out:
# 40

# %%
prev.head()
# Out:
#    Unnamed: 0            Timestamp                 Email Address  \
# 0           0                  NaN                           NaN
# 1           1  10/21/2018 22:08:57  jesslanderos098@berkeley.edu
# 2           2  10/21/2018 22:10:14       hjs9701282@berkeley.edu
# 3           3  10/21/2018 22:23:08         etshuere@berkeley.edu
# 4           4   10/22/2018 0:01:58         jihailin@berkeley.edu
#
#                Name  Census Tract  \
# 0               NaN           NaN
# 1  Jessica Landeros        4028.0
# 2        JISUE HONG        4229.0
# 3      Erica Shuere        4006.0
# 4         Jihai Lin        4224.0
#
#    On a scale of 1 - 5, where 1 is "None" and 5 is "A Lot", how many empty beer or liquor bottles are visible in streets, yards, or alleys?   \
# 0                                                NaN
# 1                                                1.0
# 2                                                2.0
# 3                                                1.0
# ...

# %%
test.head()
# Out:
#    Unnamed: 0            Timestamp                 Email Address  \
# 0           0                  NaN                           NaN
# 1           1  10/21/2018 22:08:57  jesslanderos098@berkeley.edu
# 2           2  10/21/2018 22:10:14       hjs9701282@berkeley.edu
# 3           3  10/21/2018 22:23:08         etshuere@berkeley.edu
# 4           4   10/22/2018 0:01:58         jihailin@berkeley.edu
#
#                Name  Census Tract  \
# 0               NaN           NaN
# 1  Jessica Landeros        4028.0
# 2        JISUE HONG        4229.0
# 3      Erica Shuere        4006.0
# 4         Jihai Lin        4224.0
#
#    On a scale of 1 - 5, where 1 is "None" and 5 is "A Lot", how many empty beer or liquor bottles are visible in streets, yards, or alleys?   \
# 0                                                NaN
# 1                                                1.0
# 2                                                2.0
# 3                                                1.0
# ...
